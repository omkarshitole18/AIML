# %%
# Q 1  SIMPLE CHATBOAT
import random

def simple_chatbot():
  
    greetings = ["Hello!", "Hi there!", "Hey!", "Greetings!"]

    responses = ["I'm doing well, thank you.", "Not too bad, how about you?", "I'm just a computer program, so I don't have feelings, but thanks for asking!"]

    print(random.choice(greetings))

    while True:
        user_input = input("You: ").lower()

        if user_input in ["bye", "exit", "quit"]:
            print("Bot: Goodbye! Have a great day.")
            break

        print("Bot:", random.choice(responses))

if __name__ == "__main__":
    simple_chatbot()
# Out:
# Hey!
# You:  hii
# Bot: Not too bad, how about you?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 21
#      18         print("Bot:", random.choice(responses))
#      20 if __name__ == "__main__":
# ---> 21     simple_chatbot()
#
# Cell In[1], line 12, in simple_chatbot()
#       9 print(random.choice(greetings))
#      11 while True:
# ---> 12     user_input = input("You: ").lower()
#      14     if user_input in ["bye", "exit", "quit"]:
#      15         print("Bot: Goodbye! Have a great day.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Q2 BFS
from collections import defaultdict

class Graph:
    def __init__(self):
        self.graph = defaultdict(list)

    def add_edge(self, u, v):
        self.graph[u].append(v)
        self.graph[v].append(u)  

    def bfs(self, start):
        visited = set()
        queue = [start]
        visited.add(start)

        while queue:
            current_vertex = queue.pop(0)
            print(current_vertex, end=' ')

            for neighbor in self.graph[current_vertex]:
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)

if __name__ == "__main__":
    g = Graph()
    g.add_edge(0, 1)
    g.add_edge(0, 2)
    g.add_edge(1, 3)
    g.add_edge(2, 1)
    g.add_edge(2, 3)
    g.add_edge(3, 3)

    start_vertex = 0
    print(f"BFS Traversal starting from vertex {start_vertex}:")
    g.bfs(start_vertex)
# Out:
# BFS Traversal starting from vertex 0:
# 0 1 2 3

# %%
# Q3 Dfs

class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, u, v):
        if u not in self.graph:
            self.graph[u] = []
        if v not in self.graph:
            self.graph[v] = []

        self.graph[u].append(v)
        self.graph[v].append(u)  

    def dfs(self, start, visited=None):
        if visited is None:
            visited = set()

        visited.add(start)
        print(start, end=' ')

        for neighbor in self.graph[start]:
            if neighbor not in visited:
                self.dfs(neighbor, visited)


if __name__ == "__main__":
    g = Graph()
    g.add_edge(0, 1)
    g.add_edge(0, 2)
    g.add_edge(1, 3)
    g.add_edge(2, 1)
    g.add_edge(2, 3)
    g.add_edge(3, 3)

    start_vertex = 0
    print(f"DFS Traversal starting from vertex {start_vertex}:")
    g.dfs(start_vertex)
# Out:
# DFS Traversal starting from vertex 0:
# 0 1 3 2

# %%
#Water jug problem
def water_jug_problem(capacity_a, capacity_b, target):
    state_a, state_b = 0, 0  
    print(f"Initial State: Jug A={state_a}, Jug B={state_b}")

    while state_a != target or state_b != target:
        
        if state_a < capacity_a:
            state_a = capacity_a
            print(f"Fill Jug A: Jug A={state_a}, Jug B={state_b}")

        pour = min(state_a, capacity_b - state_b)
        state_a -= pour
        state_b += pour
        print(f"Pour water from Jug A to Jug B: Jug A={state_a}, Jug B={state_b}")

       
        if state_a == target or state_b == target:
            break

        
        if state_b == capacity_b:
            state_b = 0
            print(f"Empty Jug B: Jug A={state_a}, Jug B={state_b}")
            
      
        pour = min(state_a, capacity_b - state_b)
        state_a -= pour
        state_b += pour
        print(f"Pour water from Jug A to Jug B: Jug A={state_a}, Jug B={state_b}")
        

    print(f"Target reached! Jug A={state_a}, Jug B={state_b}")


if __name__ == "__main__":
    water_jug_problem(4, 3, 2)
# Out:
# Initial State: Jug A=0, Jug B=0
# Fill Jug A: Jug A=4, Jug B=0
# Pour water from Jug A to Jug B: Jug A=0, Jug B=4
# Pour water from Jug B to Jug A: Jug A=4, Jug B=0
# Pour water from Jug A to Jug B: Jug A=0, Jug B=4
# Fill Jug A: Jug A=4, Jug B=4
# Pour water from Jug A to Jug B: Jug A=1, Jug B=7
# Empty Jug B: Jug A=1, Jug B=0
# Pour water from Jug B to Jug A: Jug A=1, Jug B=0
# Pour water from Jug A to Jug B: Jug A=0, Jug B=1
# Fill Jug A: Jug A=4, Jug B=1
# Pour water from Jug A to Jug B: Jug A=0, Jug B=5
# Pour water from Jug B to Jug A: Jug A=4, Jug B=1
# Pour water from Jug A to Jug B: Jug A=0, Jug B=5
# Fill Jug A: Jug A=4, Jug B=5
# Pour water from Jug A to Jug B: Jug A=2, Jug B=7
# Empty Jug B: Jug A=2, Jug B=0
# Pour water from Jug B to Jug A: Jug A=2, Jug B=0
# Pour water from Jug A to Jug B: Jug A=0, Jug B=2
# Fill Jug A: Jug A=4, Jug B=2
# Pour water from Jug A to Jug B: Jug A=0, Jug B=6
# Pour water from Jug B to Jug A: Jug A=4, Jug B=2
# Pour water from Jug A to Jug B: Jug A=0, Jug B=6
# Fill Jug A: Jug A=4, Jug B=6
# Pour water from Jug A to Jug B: Jug A=3, Jug B=7
# Target reached! Jug A=3, Jug B=7

# %%
#Best First Search
import heapq
class Graph:
    def __init__(self):
        self.graph = {}

    def add_edge(self, u, v, weight=None):
        if u not in self.graph:
            self.graph[u] = []
        if v not in self.graph:
            self.graph[v] = []

        weight = weight if weight is not None else 1

        self.graph[u].append((v, weight))
        self.graph[v].append((u, weight))  

    def best_first_search(self, start, goal, heuristic_values):
        visited = set()
        priority_queue = [(heuristic_values[start], start)] 

        while priority_queue:
            _, current_node = heapq.heappop(priority_queue)
            print(current_node, end=' ')

            if current_node == goal:
                print("\nGoal reached!")
                return

            visited.add(current_node)

            for neighbor, weight in self.graph[current_node]:
                if neighbor not in visited:
                    heapq.heappush(priority_queue, (heuristic_values[neighbor], neighbor))


if __name__ == "__main__":
    g = Graph()
    g.add_edge('A', 'B')
    g.add_edge('A', 'C')
    g.add_edge('B', 'D')
    g.add_edge('B', 'E')
    g.add_edge('C', 'F')
    g.add_edge('D', 'G')
    g.add_edge('E', 'H')
    g.add_edge('F', 'I')
    
    start_node = 'A'
    goal_node = 'I'
    
    heuristic_values = {
        'A': 12,
        'B': 8,
        'C': 15,
        'D': 1,
        'E': 8,
        'F': 8,
        'G': 7,
        'H': 5,
        'I': 0
    }

    print(f"Best-First Search Traversal from {start_node} to {goal_node}:")
    g.best_first_search(start_node, goal_node, heuristic_values)
# Out:
# Best-First Search Traversal from A to I:
# A B D G E H C F I
# Goal reached!

# %%
#python program to implement Missionaries and Cannibals problem
from collections import deque
def is_valid_state(state):
    left_m, left_c, boat, right_m, right_c = state
    
    if left_m > 0 and left_m < left_c:
        return False
    if right_m > 0 and right_m < right_c:
        return False  
    return True

def get_next_states(state):
    left_m, left_c, boat, right_m, right_c = state
    next_states = []
    
    if boat == 1: 
        for dm in range(3):
            for dc in range(3):
                if 0 < dm + dc <= 2:
                    new_left_m = left_m - dm
                    new_left_c = left_c - dc
                    new_right_m = right_m + dm
                    new_right_c = right_c + dc
                    new_boat = 0
                    new_state = (new_left_m, new_left_c, new_boat, new_right_m, new_right_c)
                    if is_valid_state(new_state):
                        next_states.append(new_state)
    else: 
        for dm in range(3):
            for dc in range(3):
                if 0 < dm + dc <= 2:
                    new_left_m = left_m + dm
                    new_left_c = left_c + dc
                    new_right_m = right_m - dm
                    new_right_c = right_c - dc
                    new_boat = 1
                    new_state = (new_left_m, new_left_c, new_boat, new_right_m, new_right_c)
                    if is_valid_state(new_state):
                        next_states.append(new_state)  
    return next_states

def bfs_missionaries_and_cannibals():
    initial_state = (3, 3, 1, 0, 0)  
    queue = deque([(initial_state, [])]) 
    visited = set()
    visited.add(initial_state)
    
    while queue:
        current_state, path = queue.popleft()
        
        if current_state == (0, 0, 0, 3, 3):
            return path
        
        for next_state in get_next_states(current_state):
            if next_state not in visited:
                visited.add(next_state)
                queue.append((next_state, path + [current_state]))   
    return None

def print_solution(solution):
    if solution is None:
        print("No solution found.")
    else:
        print("Solution steps:")
        for i, state in enumerate(solution):
            left_m, left_c, boat, right_m, right_c = state
            if boat == 1:
                print(f"Step {i + 1}: Move {'M'*left_m + 'C'*left_c} from left to right.")
            else:
                print(f"Step {i + 1}: Move {'M'*right_m + 'C'*right_c} from right to left.")

def main():
    solution = bfs_missionaries_and_cannibals()
    print_solution(solution)

if __name__ == "__main__":
    main()
# Out:
# 	Game Start
# Now the task is to move all of them to right side of the river
# rules:
# 1. The boat can carry at most two people
# 2. If cannibals num greater than missionaries then the cannibals would eat the missionaries
# 3. The boat cannot cross the river by itself with no people on board
#
# M M M C C C |	 --- |
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 2
#
#
# M M M C | --> | C C
#
# Right side -> Left side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 1
#
#
# M M M C C | <-- | C
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 2
#
#
# M M M | --> | C C C
#
# Right side -> Left side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 1
#
#
# M M M C | <-- | C C
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 2
# Enter number of Cannibals travel => 0
#
#
# M C | --> | M M C C
#
# Right side -> Left side river travel
# Enter number of Missionaries travel => 1
# Enter number of Cannibals travel => 1
#
#
# M M C C | <-- | M C
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 2
# Enter number of Cannibals travel => 0
#
#
# C C | --> | M M M C
#
# Right side -> Left side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 2
# Wrong input re-enter :
# Right side -> Left side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 1
#
#
# C C C | <-- | M M M
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 2
#
#
# C | --> | M M M C C
#
# Right side -> Left side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 1
#
#
# C C | <-- | M M M C
#
# Left side -> right side river travel
# Enter number of Missionaries travel => 0
# Enter number of Cannibals travel => 2
#
#
# | --> | M M M C C C
#
# You won the game :
# 	Congrats
# Total attempt
# 11

# %%
#Implement A* Search
import heapq

class Puzzle8:
    def __init__(self, initial_state, goal_state):
        self.initial_state = initial_state
        self.goal_state = goal_state

    def is_goal_state(self, state):
        return state == self.goal_state

    def get_blank_position(self, state):
        for i in range(3):
            for j in range(3):
                if state[i][j] == 0:
                    return i, j

    def generate_next_states(self, state):
        blank_row, blank_col = self.get_blank_position(state)
        next_states = []

       
        moves = [(1, 0), (-1, 0), (0, 1), (0, -1)]

        for move in moves:
            new_row, new_col = blank_row + move[0], blank_col + move[1]

            if 0 <= new_row < 3 and 0 <= new_col < 3:
                new_state = [row.copy() for row in state]
                new_state[blank_row][blank_col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[blank_row][blank_col]
                next_states.append(new_state)

        return next_states

    def manhattan_distance(self, state):
        distance = 0

        for i in range(3):
            for j in range(3):
                value = state[i][j]
                if value != 0:
                    goal_row, goal_col = divmod(value - 1, 3)
                    distance += abs(i - goal_row) + abs(j - goal_col)

        return distance

    def astar_search(self):
        priority_queue = [(self.manhattan_distance(self.initial_state), 0, self.initial_state)]
        visited = set()

        while priority_queue:
            _, cost, current_state = heapq.heappop(priority_queue)


            if tuple(map(tuple, current_state)) not in visited:
                print(f"Visiting state:\n{current_state}, Cost: {cost}")

                visited.add(tuple(map(tuple, current_state)))

                for next_state in self.generate_next_states(current_state):
                    if tuple(map(tuple, next_state)) not in visited:
                        total_cost = cost + 1
                        priority = total_cost + self.manhattan_distance(next_state)
                        heapq.heappush(priority_queue, (priority, total_cost, next_state))
            if self.is_goal_state(current_state):
                print("Goal reached!")
                return

        print("Goal not reached.")

if __name__ == "__main__":
    initial_state = [
        [1, 2, 3],
        [0, 4, 6],
        [7, 5, 8]
    ]

    goal_state = [
        [1, 2, 3],
        [4, 5, 6],
        [7, 8, 0]
    ]

    puzzle = Puzzle8(initial_state, goal_state)
    print("A* Search for 8-Puzzle:")
    puzzle.astar_search()
# Out:
# A* Search for 8-Puzzle:
# Visiting state:
# [[1, 2, 3], [0, 4, 6], [7, 5, 8]], Cost: 0
# Visiting state:
# [[1, 2, 3], [4, 0, 6], [7, 5, 8]], Cost: 1
# Visiting state:
# [[1, 2, 3], [4, 5, 6], [7, 0, 8]], Cost: 2
# Visiting state:
# [[1, 2, 3], [4, 5, 6], [7, 8, 0]], Cost: 3
# Goal reached!
